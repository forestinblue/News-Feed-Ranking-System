# %% [markdown]
# ## score = Recency(최신성) + Popularity(대중성) + Affinity(친밀성)
#
#
# - score 만점: 100
# - 최신성 만점: 50  / 대중성 만점: 30 / 친밀성: 20

# %% [markdown]
# ## 최신성(50):
# Recency score = 0
#    #DataBase: Reviews
#       -> Reviews 의 createdAt 으로 점수 측정 \
#       createdAt이 현재시간으로부터 1일이내:Recency score = 50 \
#       createdAt이 현재시간으로부터 3일이내:Recency score =  40 \
#       createdAt이 현재시간으로부터 7일이내 :Recency score = 30 \
#       createdAt이 현재시간으로부터 14일이내:Recency score = 20 \
#       createdAt이 현재시간으로부터 30일이내:Recency score = 10 \
#       else: Recency score = 0
#
#
# #score값은 max값은 변하지 않되, 스택을 계속 쌓는 식으로
# 기존의 score를 추가로 수정하지는 않고,추가되는 것들만 계속하는 식

# %% [markdown]
# ## 대중성(30):
# Popularity score = 0
#
#     #DataBase: ReviewLikes  -> maximum: 10점
#         ReviewLikes에서 reviewId 갯수 측정
#         for ReviewLikes의 전체 갯수:
#             각 ReviewID마다 ReviewLikes의 개수 측정
#             ReviewID의 ReviewLikes가 10 이상:
#                 if v
#                 Popularity score  += 10
#             ReviewID의 ReviewLikes가 80% 이상:
#                 Popularity score  += 8
#             ReviewID의 ReviewLikes가 10개 이상:
#                 Popularity score  += 6
#             ReviewID의 ReviewLikes가 5개 이상:
#                 Popularity score  += 4
#             ReviewID의 ReviewLikes가 3개 이상:
#                 Popularity score  += 2
#             else:
#                 Popularity score  += 0
#
# #현재 maximum reviewlikes 개수를 파악하고 -> n개라고 했을떄
# #n개를 분모로 두고 score값을 구하자
# #3
#
#     #DataBase: ReviewComments -> maximum: 10점
#         ReviewComments에서 reviewId 갯수 측정
#         for ReviewComment의 전체 갯수:
#             각 ReviewID마다 ReviewComments 개수 측정
#             ReviewID의 ReviewComments가 30개 이상:
#                     if 현재시간 1일 이내 30
#                     if 현재시간 1주일 이내  20
#                     if 현재시간
#                 Popularity score  += 10
#             ReviewID의 ReviewComments가 20개 이상:
#                 Popularity score  += 8
#             ReviewID의 ReviewComments가 10개 이상:
#                 Popularity score  += 6
#             ReviewID의 ReviewComments가 5개 이상:
#                 Popularity score  += 4
#             ReviewID의 ReviewComments가 3개 이상:
#                 Popularity score  += 2
#             else:
#                 Popularity score  += 0
#
#     #DataBase: UserFollows -> maximum: 10점
#         DB UserFollows 에서 followerId로 점수 측정
#         각 유저(UserID)별 followerId 갯수 측정
#         for i in 모든 유저에 대해:
#                 유저 의 len(followerId)이 30개 이상:
#                 UserID = i 유저의 reviewID score  += 10
#             유저 의 len(followerId)이 20개 이상:
#                 UserID = i 유저의 reviewID score  += 8
#             유저 의 len(followerId)이 10개 이상:
#                 UserID = i 유저의 reviewID score  += 6
#             유저 의 len(followerId)이 5개 이상:
#                 UserID = i 유저의 reviewID score  += 4
#             유저 의 len(followerId)이 3개 이상:
#                 UserID = i 유저의 reviewID score  += 2
#             else: 0

# %% [markdown]
# ## 친밀성(20)- UserID마다 ReviewID의 Affinity score 달라짐
# Affinity score = 0
# 대중성, 최신성으로 100개리뷰 뽑은 다음,
# 100개 리뷰에 대한 친밀성 계산
#
# 300개 Review dataframe에 대해  - ReviewID, UserID, Popularity
# 1. sample 함수 써서 100개 추출
# 2.
#     #DataBase: UserFollows -> maximum: 5점
#
#         리뷰를 쓴 사라람이 팔로우한 사람인가?
#     #DataBase: BookmarkReviews -> maximum: 5점
#
#         DB BookmarkReviews에서 reviewId로 점수 측정
#         리뷰 쓴 사람의 모든 리뷰 중 하나라도 북마크를 했냐?
#         if max() 점수 매기는것
#
#     #DataBase: ReviewComments -> maximum: 5점
#         리뷰 쓴 사람의 모든 리뷰 중 하나라도 리뷰 댓글을 썼냐?
#         IF  점수 차등이로 (MAX)
#     #DataBase: ReviewLikes -> maximum: 5점
#        리뷰 쓴 사람의 모든 리뷰 중 하나라도 따봉을 눌렀나?
#        IF 차등 점수 매기기
#
# #최신성은 나중에 고려
# #컨텐츠를 보고 있는 시간 -> 나중에 고려

# %% [markdown]
# # 친밀성
#
# ## UserID-UserID로 계산 (UserID-ReviewID가 아니라)
#
# (나중엔 First in First Out -Queue 스택 처럼 하다. 기존에 계산된 친밀성을 반복해서 계산하지 않도록)
#
# 피드를 사용하는 사람과 관련업는 리뷰는
# 사용자 하고 관련 된 것 것들 이 두개를 따로 다루다
# 공통적인 것들은 한시간 마다 계산하고 -> (항상 최신이 아니어도 상관없다)
#
# 친구의 소식을 바로 알면 좋다. 그런 사람의 리뷰는 실시간으로 불러 올수 있는 방법을 구할 수 있으면
#
# 이 두개를 조화롭게 사용하면 좋지 않을 까
#
# 공통 리뷰가 항상 같은 것만 보면 여전 -> 섞으면 괜찮다
#
# 사용자하고 연관있는 리뷰를 추리는 건 복잡해 잘 생각해보아야
#
# 사용자하고 연관된 리뷰는 저장하고
# (사용자하고 사용자간의 연관성을 알아야 한다.)
#
# 연관되지 않는 리뷰는 실시간으로
#
#
# 거리 계산
# 모든 사용자에 대한 공통 리뷰 저장하고, 거리 필터링을 하면 된다
#
# 지역별로 저장(불러 올때마다 거리 계산 x)
#
#
# 빠르고, 정확하게
#
#
#
# 리스트나 딕셔너리 입출력
# 판다스로 입출력 지양
#
# 함수가 아니라 클래스로 만들기
#
#
# 피드백 (마케팅- 수지씨)
# 본인 피드는 보이지 않도록

# %%
#DataBase: ReviewCommentLikes & ReviewComments -> maximum: 5점
        DB ReviewCommentLikes에서 senderId로 점수 측정
        for i in 모든 senderId에 대해:
           senderId의 reviewCommentId와 같은

# %%
from database import query
import time

# 최신성 스코어 구하기
def getRecencyScore(reviewId):
    global firstReviewTime, lastReviewTime
    maxScore = lastReviewTime - firstReviewTime
    sql = 'SELECT createdAt FROM Reviews WHERE id = {0}'.format(reviewId)
    review = query(sql)

    if review is None or len(review) == 0:
        return 0

    reviewTime = review[0]['createdAt']
    score = reviewTime - firstReviewTime
    return score / maxScore * 50


# 최대 리뷰 좋아요 수 구하기.
def getMaxReviewLike():
    sql = "SELECT COUNT(ReviewLikes.reviewId) FROM Reviews LEFT JOIN ReviewLikes ON ReviewLikes.reviewId = Reviews.id GROUP BY Reviews.id ORDER BY COUNT(ReviewLikes.reviewId) DESC"
    maxReviewLike = query(sql)
    return maxReviewLike[0]['COUNT(ReviewLikes.reviewId)']


# 최대 리뷰 댓글 수 구하기.
def getMaxReviewComment():
    sql = "SELECT COUNT(ReviewComments.reviewId) FROM Reviews LEFT JOIN ReviewComments ON ReviewComments.reviewId = Reviews.id GROUP BY Reviews.id ORDER BY COUNT(ReviewComments.reviewId) DESC"
    maxReviewComment = query(sql)
    return maxReviewComment[0]['COUNT(ReviewComments.reviewId)']


# 최대 유저 팔로잉 수 구하기.
def getMaxFollow():
    sql = "SELECT COUNT(UserFollows.followingId) FROM Users LEFT JOIN UserFollows ON UserFollows.followingId = Users.id GROUP BY Users.id ORDER BY COUNT(UserFollows.followingId) DESC"
    getMaxFollow = query(sql)
    return getMaxFollow[0]['COUNT(UserFollows.followingId)']


# 리뷰의 좋아요 점수 구하기.
def getScoreOfReviewLike(reviewId):
    global maxReviewScore
    sql = "SELECT COUNT(reviewId) FROM ReviewLikes WHERE reviewId = {0}".format(reviewId)
    score = query(sql)
    if score is None or len(score) == 0:
        return 0
    return score[0]['COUNT(reviewId)'] / maxReviewScore * 10


# 리뷰의 댓글 점수 구하기.
def getScoreOfReviewComment(reviewId):
    global maxCommentScore
    sql = "SELECT COUNT(id) FROM ReviewComments WHERE reviewId = {0}".format(reviewId)
    score = query(sql)
    if score is None or len(score) == 0:
        return 0
    return score[0]['COUNT(id)'] / maxCommentScore * 10

# 리뷰의 팔로우 점수 구하기.
def getScoreOfFollow(reviewId):
    global maxFollowScore
    sql = "SELECT COUNT(UserFollows.followerId) FROM UserFollows LEFT JOIN Reviews ON Reviews.authorId = UserFollows.followingId WHERE Reviews.id = {0}".format(reviewId)
    score = query(sql)
    if score is None or len(score) == 0:
        return 0
    return score[0]['COUNT(UserFollows.followerId)'] / maxFollowScore * 10

# 대중성 스코어 구하기
def getPopularityScore(reviewId):
    return getScoreOfReviewLike(reviewId) + getScoreOfReviewComment(reviewId) + getScoreOfFollow(reviewId)

# 최신성 + 대중성 점수
def getTotalScore(reviewId):
    return getRecencyScore(reviewId) + getPopularityScore(reviewId)

# 친밀성 점수 구하기
def getTasteScore(userId, reviewId):
    score = 0
    sql = 'SELECT id FROM Reviews LEFT JOIN UserFollows ON UserFollows.followingId = Reviews.authorId WHERE Reviews.id = {0} and UserFollows.followerId = {1}'.format(reviewId, userId)
    checkFollows = query(sql)
    if len(checkFollows) > 0:
        score += 5

    sql = 'SELECT * FROM BookmarkReviews ' \
          'LEFT JOIN Reviews as authorReview ON BookmarkReviews.reviewId = authorReview.id ' \
          'LEFT JOIN Reviews as seeingReview ON seeingReview.authorId = authorReview.authorId ' \
          'LEFT JOIN Bookmarks ON BookmarkReviews.bookmarkId = Bookmarks.id ' \
          'WHERE Bookmarks.userId = {0} and seeingReview.id = {1}'.format(userId, reviewId)
    checkBookmarks = query(sql)
    if len(checkBookmarks) > 0:
        score += 5

    sql = 'SELECT * FROM ReviewComments ' \
          'LEFT JOIN Reviews as authorReview ON ReviewComments.reviewId = authorReview.id ' \
          'LEFT JOIN Reviews as seeingReview ON seeingReview.authorId = authorReview.authorId ' \
          'WHERE ReviewComments.authorId = {0} and seeingReview.id = {1}'.format(userId, reviewId)
    checkComments = query(sql)
    if len(checkComments) > 0:
        score += 5

    sql = 'SELECT * FROM ReviewLikes ' \
          'LEFT JOIN Reviews as authorReview ON ReviewLikes.reviewId = authorReview.id ' \
          'LEFT JOIN Reviews as seeingReview ON seeingReview.authorId = authorReview.authorId ' \
          'WHERE ReviewLikes.senderId = {0} and seeingReview.id = {1}'.format(userId, reviewId)
    checkLikes = query(sql)
    if len(checkLikes) > 0:
        score += 5

    return score

# 메인 함수.
if __name__ == '__main__':

    maxReviewScore = getMaxReviewLike()
    maxCommentScore = getMaxReviewComment()
    maxFollowScore = getMaxFollow()

    firstReviewTime = query('SELECT createdAt FROM Reviews ORDER BY createdAt ASC LIMIT 1')[0]['createdAt']
    lastReviewTime = query('SELECT createdAt FROM Reviews ORDER BY createdAt DESC LIMIT 1')[0]['createdAt']
